# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 40000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

#!wget https://github.com/Kcops11/LearningGPT/blob/main/SpongeBob.txt
with open('SpongeBob.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print('length of dataset in characters: ' , len(text))
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=10000)[0].tolist()))
# Out:
# length of dataset in characters:  3157092
# 0.215534 M parameters
# step 0: train loss 4.9445, val loss 4.9448
# step 100: train loss 2.7047, val loss 2.7229
# step 200: train loss 2.4766, val loss 2.4898
# step 300: train loss 2.3366, val loss 2.3691
# step 400: train loss 2.2302, val loss 2.2608
# step 500: train loss 2.1499, val loss 2.1892
# step 600: train loss 2.1122, val loss 2.1185
# step 700: train loss 2.0523, val loss 2.0563
# step 800: train loss 2.0055, val loss 2.0120
# step 900: train loss 1.9509, val loss 1.9778
# step 1000: train loss 1.9254, val loss 1.9425
# step 1100: train loss 1.9018, val loss 1.9206
# step 1200: train loss 1.8817, val loss 1.9122
# step 1300: train loss 1.8469, val loss 1.8696
# step 1400: train loss 1.8193, val loss 1.8448
# step 1500: train loss 1.7996, val loss 1.8408
# step 1600: train loss 1.7914, val loss 1.8038
# step 1700: train loss 1.7737, val loss 1.7984
# step 1800: train loss 1.7634, val loss 1.7946
# step 1900: train loss 1.7533, val loss 1.7626
# step 2000: train loss 1.7171, val loss 1.7675
# step 2100: train loss 1.7236, val loss 1.7463
# step 2200: train loss 1.7034, val loss 1.7416
# step 2300: train loss 1.6972, val loss 1.7381
# step 2400: train loss 1.6913, val loss 1.7154
# step 2500: train loss 1.6771, val loss 1.7108
# step 2600: train loss 1.6741, val loss 1.7011
# step 2700: train loss 1.6613, val loss 1.6880
# step 2800: train loss 1.6623, val loss 1.6904
# step 2900: train loss 1.6409, val loss 1.6873
# step 3000: train loss 1.6520, val loss 1.6650
# step 3100: train loss 1.6369, val loss 1.6667
# step 3200: train loss 1.6243, val loss 1.6646
# step 3300: train loss 1.6293, val loss 1.6499
# step 3400: train loss 1.6129, val loss 1.6463
# step 3500: train loss 1.6053, val loss 1.6541
# step 3600: train loss 1.6008, val loss 1.6412
# step 3700: train loss 1.6058, val loss 1.6358
# step 3800: train loss 1.6087, val loss 1.6375
# step 3900: train loss 1.5974, val loss 1.6367
# step 4000: train loss 1.5827, val loss 1.6280
# step 4100: train loss 1.5865, val loss 1.6177
# step 4200: train loss 1.5706, val loss 1.6136
# step 4300: train loss 1.5763, val loss 1.6267
# step 4400: train loss 1.5581, val loss 1.6218
# step 4500: train loss 1.5629, val loss 1.6050
# step 4600: train loss 1.5631, val loss 1.6129
# step 4700: train loss 1.5691, val loss 1.6221
# step 4800: train loss 1.5610, val loss 1.6052
# step 4900: train loss 1.5571, val loss 1.6043
# step 5000: train loss 1.5472, val loss 1.6036
# step 5100: train loss 1.5430, val loss 1.5969
# step 5200: train loss 1.5280, val loss 1.5999
# step 5300: train loss 1.5342, val loss 1.5820
# step 5400: train loss 1.5302, val loss 1.5885
# step 5500: train loss 1.5373, val loss 1.5837
# step 5600: train loss 1.5190, val loss 1.5819
# step 5700: train loss 1.5163, val loss 1.5769
# step 5800: train loss 1.5247, val loss 1.5744
# step 5900: train loss 1.5283, val loss 1.5703
# step 6000: train loss 1.5161, val loss 1.5597
# step 6100: train loss 1.5197, val loss 1.5703
# step 6200: train loss 1.5258, val loss 1.5622
# step 6300: train loss 1.5220, val loss 1.5487
# step 6400: train loss 1.5094, val loss 1.5486
# step 6500: train loss 1.5151, val loss 1.5583
# step 6600: train loss 1.5121, val loss 1.5522
# step 6700: train loss 1.4968, val loss 1.5588
# step 6800: train loss 1.5007, val loss 1.5409
# step 6900: train loss 1.5007, val loss 1.5388
# step 7000: train loss 1.5029, val loss 1.5486
# step 7100: train loss 1.4993, val loss 1.5440
# step 7200: train loss 1.4929, val loss 1.5560
# step 7300: train loss 1.4937, val loss 1.5446
# step 7400: train loss 1.4837, val loss 1.5481
# step 7500: train loss 1.4846, val loss 1.5378
# step 7600: train loss 1.4865, val loss 1.5443
# step 7700: train loss 1.4807, val loss 1.5381
# step 7800: train loss 1.4870, val loss 1.5343
# step 7900: train loss 1.4753, val loss 1.5391
# step 8000: train loss 1.4715, val loss 1.5506
# step 8100: train loss 1.4712, val loss 1.5286
# step 8200: train loss 1.4826, val loss 1.5373
# step 8300: train loss 1.4742, val loss 1.5272
# step 8400: train loss 1.4722, val loss 1.5336
# step 8500: train loss 1.4686, val loss 1.5297
# step 8600: train loss 1.4900, val loss 1.5278
# step 8700: train loss 1.4661, val loss 1.5143
# step 8800: train loss 1.4648, val loss 1.5282
# step 8900: train loss 1.4748, val loss 1.5270
# step 9000: train loss 1.4628, val loss 1.5243
# step 9100: train loss 1.4781, val loss 1.5159
# step 9200: train loss 1.4765, val loss 1.5304
# step 9300: train loss 1.4612, val loss 1.5278
# step 9400: train loss 1.4697, val loss 1.5255
# step 9500: train loss 1.4642, val loss 1.5177
# step 9600: train loss 1.4683, val loss 1.5119
# step 9700: train loss 1.4664, val loss 1.5136
# step 9800: train loss 1.4629, val loss 1.5029
# step 9900: train loss 1.4562, val loss 1.5062
# step 10000: train loss 1.4522, val loss 1.5160
# step 10100: train loss 1.4669, val loss 1.5194
# step 10200: train loss 1.4427, val loss 1.5070
# step 10300: train loss 1.4498, val loss 1.5286
# step 10400: train loss 1.4621, val loss 1.5256
# step 10500: train loss 1.4374, val loss 1.4986
# step 10600: train loss 1.4383, val loss 1.5197
# step 10700: train loss 1.4581, val loss 1.4935
# step 10800: train loss 1.4535, val loss 1.4908
# step 10900: train loss 1.4343, val loss 1.5073
# step 11000: train loss 1.4415, val loss 1.4778
# step 11100: train loss 1.4356, val loss 1.5068
# step 11200: train loss 1.4295, val loss 1.4984
# step 11300: train loss 1.4482, val loss 1.5163
# step 11400: train loss 1.4351, val loss 1.4976
# step 11500: train loss 1.4409, val loss 1.4894
# step 11600: train loss 1.4324, val loss 1.4965
# step 11700: train loss 1.4297, val loss 1.4961
# step 11800: train loss 1.4434, val loss 1.4978
# step 11900: train loss 1.4219, val loss 1.4810
# step 12000: train loss 1.4184, val loss 1.5001
# step 12100: train loss 1.4303, val loss 1.4973
# step 12200: train loss 1.4306, val loss 1.4911
# step 12300: train loss 1.4304, val loss 1.4847
# step 12400: train loss 1.4321, val loss 1.4972
# step 12500: train loss 1.4445, val loss 1.4922
# step 12600: train loss 1.4318, val loss 1.4807
# step 12700: train loss 1.4353, val loss 1.4927
# step 12800: train loss 1.4281, val loss 1.4918
# step 12900: train loss 1.4376, val loss 1.4851
# step 13000: train loss 1.4294, val loss 1.4826
# step 13100: train loss 1.4251, val loss 1.4990
# step 13200: train loss 1.4243, val loss 1.4783
# step 13300: train loss 1.4097, val loss 1.4886
# step 13400: train loss 1.4113, val loss 1.4810
# step 13500: train loss 1.4170, val loss 1.4760
# step 13600: train loss 1.4102, val loss 1.4755
# step 13700: train loss 1.4234, val loss 1.4813
# step 13800: train loss 1.4153, val loss 1.4922
# step 13900: train loss 1.4190, val loss 1.4888
# step 14000: train loss 1.4244, val loss 1.4838
# step 14100: train loss 1.4111, val loss 1.4797
# step 14200: train loss 1.4121, val loss 1.4973
# step 14300: train loss 1.4182, val loss 1.4840
# step 14400: train loss 1.4162, val loss 1.4777
# step 14500: train loss 1.4144, val loss 1.4839
# step 14600: train loss 1.4080, val loss 1.4646
# step 14700: train loss 1.4169, val loss 1.4829
# step 14800: train loss 1.4126, val loss 1.4693
# step 14900: train loss 1.4273, val loss 1.4980
# step 15000: train loss 1.4064, val loss 1.4866
# step 15100: train loss 1.4076, val loss 1.4764
# step 15200: train loss 1.3981, val loss 1.4808
# step 15300: train loss 1.4098, val loss 1.4733
# step 15400: train loss 1.3943, val loss 1.4828
# step 15500: train loss 1.4169, val loss 1.4463
# step 15600: train loss 1.4038, val loss 1.4571
# step 15700: train loss 1.4019, val loss 1.4857
# step 15800: train loss 1.3917, val loss 1.4814
# step 15900: train loss 1.4013, val loss 1.4675
# step 16000: train loss 1.4044, val loss 1.4784
# step 16100: train loss 1.4100, val loss 1.4829
# step 16200: train loss 1.4041, val loss 1.4739
# step 16300: train loss 1.3958, val loss 1.4666
# step 16400: train loss 1.4094, val loss 1.4603
# step 16500: train loss 1.4058, val loss 1.4683
# step 16600: train loss 1.4189, val loss 1.4774
# step 16700: train loss 1.3966, val loss 1.4551
# step 16800: train loss 1.4057, val loss 1.4856
# step 16900: train loss 1.3992, val loss 1.4551
# step 17000: train loss 1.4002, val loss 1.4660
# step 17100: train loss 1.3888, val loss 1.4598
# step 17200: train loss 1.3926, val loss 1.4590
# step 17300: train loss 1.3847, val loss 1.4652
# step 17400: train loss 1.3812, val loss 1.4592
# step 17500: train loss 1.3780, val loss 1.4453
# step 17600: train loss 1.4044, val loss 1.4769
# step 17700: train loss 1.3967, val loss 1.4591
# step 17800: train loss 1.3922, val loss 1.4748
# step 17900: train loss 1.3841, val loss 1.4480
# step 18000: train loss 1.3909, val loss 1.4702
# step 18100: train loss 1.3980, val loss 1.4573
# step 18200: train loss 1.3886, val loss 1.4679
# step 18300: train loss 1.3993, val loss 1.4571
# step 18400: train loss 1.3958, val loss 1.4594
# step 18500: train loss 1.3822, val loss 1.4657
# step 18600: train loss 1.3837, val loss 1.4550
# step 18700: train loss 1.3907, val loss 1.4633
# step 18800: train loss 1.3906, val loss 1.4604
# step 18900: train loss 1.3829, val loss 1.4448
# step 19000: train loss 1.3857, val loss 1.4657
# step 19100: train loss 1.3841, val loss 1.4418
# step 19200: train loss 1.3870, val loss 1.4552
# step 19300: train loss 1.3734, val loss 1.4516
# step 19400: train loss 1.3809, val loss 1.4525
# step 19500: train loss 1.3920, val loss 1.4620
# step 19600: train loss 1.3859, val loss 1.4550
# step 19700: train loss 1.3827, val loss 1.4489
# step 19800: train loss 1.3927, val loss 1.4601
# step 19900: train loss 1.3817, val loss 1.4556
# step 20000: train loss 1.3847, val loss 1.4678
# step 20100: train loss 1.3827, val loss 1.4574
# step 20200: train loss 1.3867, val loss 1.4600
# step 20300: train loss 1.3770, val loss 1.4634
# step 20400: train loss 1.3835, val loss 1.4414
# step 20500: train loss 1.3779, val loss 1.4572
# step 20600: train loss 1.3760, val loss 1.4576
# step 20700: train loss 1.3718, val loss 1.4485
# step 20800: train loss 1.3724, val loss 1.4527
# step 20900: train loss 1.3745, val loss 1.4488
# step 21000: train loss 1.3737, val loss 1.4552
# step 21100: train loss 1.3669, val loss 1.4582
# step 21200: train loss 1.3774, val loss 1.4457
# step 21300: train loss 1.3773, val loss 1.4387
# step 21400: train loss 1.3795, val loss 1.4597
# step 21500: train loss 1.3815, val loss 1.4394
# step 21600: train loss 1.3795, val loss 1.4483
# step 21700: train loss 1.3825, val loss 1.4473
# step 21800: train loss 1.3898, val loss 1.4513
# step 21900: train loss 1.3839, val loss 1.4446
# step 22000: train loss 1.3773, val loss 1.4490
# step 22100: train loss 1.3712, val loss 1.4471
# step 22200: train loss 1.3625, val loss 1.4480
# step 22300: train loss 1.3633, val loss 1.4463
# step 22400: train loss 1.3655, val loss 1.4415
# step 22500: train loss 1.3759, val loss 1.4366
# step 22600: train loss 1.3684, val loss 1.4418
# step 22700: train loss 1.3690, val loss 1.4395
# step 22800: train loss 1.3767, val loss 1.4465
# step 22900: train loss 1.3687, val loss 1.4607
# step 23000: train loss 1.3666, val loss 1.4542
# step 23100: train loss 1.3665, val loss 1.4568
# step 23200: train loss 1.3676, val loss 1.4377
# step 23300: train loss 1.3681, val loss 1.4477
# step 23400: train loss 1.3875, val loss 1.4498
# step 23500: train loss 1.3662, val loss 1.4399
# step 23600: train loss 1.3614, val loss 1.4391
# step 23700: train loss 1.3709, val loss 1.4466
# step 23800: train loss 1.3697, val loss 1.4476
# step 23900: train loss 1.3714, val loss 1.4532
# step 24000: train loss 1.3590, val loss 1.4374
# step 24100: train loss 1.3669, val loss 1.4508
# step 24200: train loss 1.3773, val loss 1.4421
# step 24300: train loss 1.3710, val loss 1.4393
# step 24400: train loss 1.3629, val loss 1.4456
# step 24500: train loss 1.3697, val loss 1.4352
# step 24600: train loss 1.3602, val loss 1.4411
# step 24700: train loss 1.3669, val loss 1.4484
# step 24800: train loss 1.3653, val loss 1.4457
# step 24900: train loss 1.3672, val loss 1.4549
# step 25000: train loss 1.3644, val loss 1.4332
# step 25100: train loss 1.3628, val loss 1.4398
# step 25200: train loss 1.3558, val loss 1.4310
# step 25300: train loss 1.3534, val loss 1.4319
# step 25400: train loss 1.3513, val loss 1.4260
# step 25500: train loss 1.3717, val loss 1.4374
# step 25600: train loss 1.3642, val loss 1.4383
# step 25700: train loss 1.3618, val loss 1.4406
# step 25800: train loss 1.3557, val loss 1.4343
# step 25900: train loss 1.3644, val loss 1.4332
# step 26000: train loss 1.3536, val loss 1.4408
# step 26100: train loss 1.3595, val loss 1.4349
# step 26200: train loss 1.3657, val loss 1.4213
# step 26300: train loss 1.3594, val loss 1.4453
# step 26400: train loss 1.3489, val loss 1.4438
# step 26500: train loss 1.3639, val loss 1.4330
# step 26600: train loss 1.3580, val loss 1.4282
# step 26700: train loss 1.3640, val loss 1.4336
# step 26800: train loss 1.3481, val loss 1.4281
# step 26900: train loss 1.3602, val loss 1.4334
# step 27000: train loss 1.3559, val loss 1.4466
# step 27100: train loss 1.3547, val loss 1.4418
# step 27200: train loss 1.3491, val loss 1.4449
# step 27300: train loss 1.3564, val loss 1.4274
# step 27400: train loss 1.3617, val loss 1.4417
# step 27500: train loss 1.3530, val loss 1.4448
# step 27600: train loss 1.3497, val loss 1.4431
# step 27700: train loss 1.3611, val loss 1.4296
# step 27800: train loss 1.3590, val loss 1.4312
# step 27900: train loss 1.3436, val loss 1.4375
# step 28000: train loss 1.3596, val loss 1.4263
# step 28100: train loss 1.3511, val loss 1.4241
# step 28200: train loss 1.3596, val loss 1.4369
# step 28300: train loss 1.3555, val loss 1.4257
# step 28400: train loss 1.3565, val loss 1.4333
# step 28500: train loss 1.3532, val loss 1.4192
# step 28600: train loss 1.3422, val loss 1.4267
# step 28700: train loss 1.3566, val loss 1.4246
# step 28800: train loss 1.3653, val loss 1.4358
# step 28900: train loss 1.3594, val loss 1.4436
# step 29000: train loss 1.3479, val loss 1.4358
# step 29100: train loss 1.3564, val loss 1.4370
# step 29200: train loss 1.3509, val loss 1.4322
# step 29300: train loss 1.3494, val loss 1.4223
# step 29400: train loss 1.3535, val loss 1.4215
# step 29500: train loss 1.3545, val loss 1.4287
# step 29600: train loss 1.3525, val loss 1.4204
# step 29700: train loss 1.3529, val loss 1.4263
# step 29800: train loss 1.3525, val loss 1.4177
# step 29900: train loss 1.3454, val loss 1.4200
# step 30000: train loss 1.3494, val loss 1.4385
# step 30100: train loss 1.3409, val loss 1.4311
# step 30200: train loss 1.3463, val loss 1.4163
# step 30300: train loss 1.3651, val loss 1.4259
# step 30400: train loss 1.3508, val loss 1.4182
# step 30500: train loss 1.3548, val loss 1.4268
# step 30600: train loss 1.3594, val loss 1.4187
# step 30700: train loss 1.3466, val loss 1.4165
# step 30800: train loss 1.3511, val loss 1.4242
# step 30900: train loss 1.3526, val loss 1.4149
# step 31000: train loss 1.3421, val loss 1.4353
# step 31100: train loss 1.3323, val loss 1.4190
# step 31200: train loss 1.3494, val loss 1.4226
# step 31300: train loss 1.3355, val loss 1.4298
# step 31400: train loss 1.3388, val loss 1.4140
# step 31500: train loss 1.3467, val loss 1.4310
# step 31600: train loss 1.3372, val loss 1.4204
# step 31700: train loss 1.3448, val loss 1.4377
# step 31800: train loss 1.3483, val loss 1.4180
# step 31900: train loss 1.3429, val loss 1.4290
# step 32000: train loss 1.3511, val loss 1.4154
# step 32100: train loss 1.3499, val loss 1.4356
# step 32200: train loss 1.3389, val loss 1.4061
# step 32300: train loss 1.3419, val loss 1.4225
# step 32400: train loss 1.3444, val loss 1.4135
# step 32500: train loss 1.3358, val loss 1.4244
# step 32600: train loss 1.3356, val loss 1.4210
# step 32700: train loss 1.3520, val loss 1.4222
# step 32800: train loss 1.3347, val loss 1.4197
# step 32900: train loss 1.3446, val loss 1.4187
# step 33000: train loss 1.3307, val loss 1.4196
# step 33100: train loss 1.3396, val loss 1.4147
# step 33200: train loss 1.3265, val loss 1.4025
# step 33300: train loss 1.3323, val loss 1.4174
# step 33400: train loss 1.3514, val loss 1.4263
# step 33500: train loss 1.3307, val loss 1.4129
# step 33600: train loss 1.3328, val loss 1.4301
# step 33700: train loss 1.3403, val loss 1.4255
# step 33800: train loss 1.3270, val loss 1.4061
# step 33900: train loss 1.3445, val loss 1.4243
# step 34000: train loss 1.3399, val loss 1.4276
# step 34100: train loss 1.3440, val loss 1.4226
# step 34200: train loss 1.3545, val loss 1.4163
# step 34300: train loss 1.3477, val loss 1.4213
# step 34400: train loss 1.3468, val loss 1.4233
# step 34500: train loss 1.3361, val loss 1.4305
# step 34600: train loss 1.3398, val loss 1.4122
# step 34700: train loss 1.3454, val loss 1.4173
# step 34800: train loss 1.3512, val loss 1.4295
# step 34900: train loss 1.3371, val loss 1.4308
# step 35000: train loss 1.3376, val loss 1.4136
# step 35100: train loss 1.3338, val loss 1.4065
# step 35200: train loss 1.3416, val loss 1.4288
# step 35300: train loss 1.3313, val loss 1.4317
# step 35400: train loss 1.3197, val loss 1.4156
# step 35500: train loss 1.3438, val loss 1.4070
# step 35600: train loss 1.3331, val loss 1.4255
# step 35700: train loss 1.3300, val loss 1.4096
# step 35800: train loss 1.3352, val loss 1.4253
# step 35900: train loss 1.3270, val loss 1.4163
# step 36000: train loss 1.3439, val loss 1.4172
# step 36100: train loss 1.3311, val loss 1.4147
# step 36200: train loss 1.3305, val loss 1.4068
# step 36300: train loss 1.3370, val loss 1.4169
# step 36400: train loss 1.3378, val loss 1.4196
# step 36500: train loss 1.3363, val loss 1.4183
# step 36600: train loss 1.3305, val loss 1.4104
# step 36700: train loss 1.3257, val loss 1.4170
# step 36800: train loss 1.3314, val loss 1.4198
# step 36900: train loss 1.3312, val loss 1.4171
# step 37000: train loss 1.3431, val loss 1.4140
# step 37100: train loss 1.3366, val loss 1.4187
# step 37200: train loss 1.3312, val loss 1.4256
# step 37300: train loss 1.3189, val loss 1.4142
# step 37400: train loss 1.3393, val loss 1.4175
# step 37500: train loss 1.3304, val loss 1.4210
# step 37600: train loss 1.3358, val loss 1.4193
# step 37700: train loss 1.3418, val loss 1.4184
# step 37800: train loss 1.3186, val loss 1.4244
# step 37900: train loss 1.3438, val loss 1.4206
# step 38000: train loss 1.3290, val loss 1.4067
# step 38100: train loss 1.3473, val loss 1.4258
# step 38200: train loss 1.3295, val loss 1.4134
# step 38300: train loss 1.3333, val loss 1.4027
# step 38400: train loss 1.3377, val loss 1.4100
# step 38500: train loss 1.3296, val loss 1.4125
# step 38600: train loss 1.3294, val loss 1.4119
# step 38700: train loss 1.3390, val loss 1.4194
# step 38800: train loss 1.3431, val loss 1.4119
# step 38900: train loss 1.3203, val loss 1.4051
# step 39000: train loss 1.3446, val loss 1.4095
# step 39100: train loss 1.3321, val loss 1.3993
# step 39200: train loss 1.3269, val loss 1.4093
# step 39300: train loss 1.3191, val loss 1.4114
# step 39400: train loss 1.3178, val loss 1.4143
# step 39500: train loss 1.3313, val loss 1.4268
# step 39600: train loss 1.3233, val loss 1.4036
# step 39700: train loss 1.3339, val loss 1.4111
# step 39800: train loss 1.3255, val loss 1.4048
# step 39900: train loss 1.3252, val loss 1.4093
# step 39999: train loss 1.3253, val loss 1.3971
#
#
# Fun, I made about your card?
#
# SpongeBob: OK.K.... (Squidward sighs)
#
# SpongeBob: (smiles somegame, the good to kid, certain high mats' to feved yoursest. Ye was his road of This arounded. Onces the desidens change about? Krabs, two have down the cool ---
#
#
# Old Man Jack: So, what hit yelliables. (gets tumbs him in exwerlance on Planktozed and snats inters the cameras, twice Pal, with a short office over the officersative. The door screens, SpongeBob founded Oday, thick.
#
# Lary: Well, (turns his billical. It fist, acture to get on Sponge Squidward is ene drink)
#
# SpongeBob: I made this is kitting zoob laughing)
#
# Pland: (everyone then turned around my mast... (Smelly shrill dristand) ASHAHHHHHHHHHHHHHHHHHHHHHHHHHHHHH!!, anyway! Thou're begins to have see a spriking, a informarily in father)
#
# Squidward: I talk to walk away?
#
# SpongeBob: Pa l.spray badging to coms him in a (inmights him around...
# Mr. Krabs: I am wave who happened to these puts for Clameranger) Hait you to hear that school bathing this plature one? Thereveae the topper egg arenouse)
# Uh-huh, Gull TV! (and guy walkies into Patrick! This right Now and boying bubbles, sake is Kraby Patty again. (begins cutil a vents and we gets mind. Stay down the cloth standse? Aye, Squidward!
#
# Squidma. Party core and Both less cup to look love-goow at Squidward oves something that I ain’t the Krabby Patty?
#
# SpongeBob: Give me who that would see. (cut to SpongeBob grandabs’. Perch undertainly into the sun bac until the asleas) Pandints the triple trace me to back Joint Pardon! (takes a cartoe where Squidward, drop out. (and then them swoulder.
#
# Timmitor: Ah, what he, Mr. Krabs?
#
# Plankton: Please collet in the door out his cleaning office) It would nut eelevenium to one a good) Peccied in cheat this boys. The patty on the screen safe, the butts cheels out. Sun pulls something) Don't you tryow you can wear now.
#
# SpongeBob: (opens the Krubby Patty) Whas don't night tay?
#
# Patrick: You today's sea? (SpongeBob growling startedly. put you area on this inded like it boots. They're going to even cest I want my Smilics seating all fever anything up to use?
#
# Patrick: Now that's a well qulear. (we goes new in the customer again)
#
# Mr. Pinside Squidward: Hey! (SpongeBob cumming begins for to worried show their food and Squidward, SpongeBob, the tree sending?
#
# Patrick: Quiet, angrily, gets say him butts a wreal Worn pullicer on thow)
#
# Patrick: Are, that we. (goes up up,ound him is not now another, my side minute? (gasps to the tape. Squidward growls his tone around then me, a stick relist. I know you guy I'll you aben I means your note good!
#
# Mr. Krabs: We're you going to wsets you sigh the coffinter to this lach big taller, and me challenge your pager. (is cerean tie) Uh horray out of them formula?
# Offsnling, new then we go? (slams Officked.
#
# Squidward: (laughing) Uh...0...
#
# Mr. Krabs: (yourself to go get out underwerwour! (pulling up to hold after the cray at the darton 'I go to? I told you go into a mug of aren't mast Krabs curing this licker while, my cup for Squidward.
# (SpongeBob doest, here, Patrick. (back can I might! A with thingy. You're goned hit autily, use everyone)
# Pavie #2: Kare and paytoar!
#
# Creesemer? And Best Gary.
#
# SpongeBob: Hey, yeah, sidewa-wa-w-hais! Aww, apensand...chave even to that goes. (pulls down Kisse) Perhappeticy to SpongeBob) ...that, oh, Patrick? (lifts tager)
#
# SpongeBob: No, with Next Patrick.
# All: Gull you see hours what get guy he's Mr. Krabs' erraness, when appens this one whistle plumber? Did you naket make Mr. Krabs: There, just waitinl, where I'll get a "Krabby Patty guy on the customer is alagight... (oKens]
#
# Patrick: Look, I thought wears thing nocevaling: Mone on the tunet) Oh, uh, muscry look at the stain) Drawlwing!
#
# SpongeBob: Ye-haheaha! SpongeBob, don't look away for you indoors?
#
# Squidward: Panting on the dumping.
#
# SpongeBob: It's a does shelling, the flyong time, we happened to get it)
#
# SpongeBob: SpongeBob?
# SpongeBob: So, it is still around.
# Gary: I'll try chat scene to go another busit then cuts it his turns downted)
#
# (Realion shows h.)That passie, yes-fly-um-tick. (Patrick lives up) Patrick and Patrick SpongeBob founder card-als. The bell of the grill)(clothes hocerse then screams away, livie-ki tojelev there is itepique I know what?
#
# (A stickers and 3 reed friends laughing) Perfect something and reading in pal-earled)
#
# SpongeBob: Doctor!
#
# Barnacle Magic Boaty Kraught Test Gump?
#
# SpongeBob: Don't want to see this. Get come down his! (laughs everybody in this hand. So! Squidward. SpongeBob, cuts to it! SpongeBob was love...
# Bared Mr. Krabs: (running around his money) Hold a ballowy! (who slips awa stuft bop) Why don't you not turing.
#
# Patrick: Yeah, huh? Core there's Place! (walks off) Let's like with the Mermaid Man: Booost run! (scene runs to
#
# Sandy: Oh, okay, Dollars SpongeBob. (standing a plare and Cloself-eirantazings has he erease, and then normal) Uh-eh, we see see you what?
# SpongeBob: Patrick, noww... Commerabes...I.. (Mr. Krabs' alone, attachion, right kids. (Squidward staps vagger? Sa, that's hand what do you can the helmets...and then patty Scelfiver the crowd been is yourselvel me.
#
# SpongeBob: Really first, Squidward, comming. Yere you used when turns then may ston) The pipe enough Patrick will called! Had stupide of this rolling with the day. He talks off-hi-da... away!
#
# Squidward: I Love! (SpongeBob smiles a wooder-petice from his seonet in Whidecturitsfor is yoursleed in his drawn) No. Oh now now, that, that's? No! A cannor imagey, I'll eat you can't get out the back! (bus ducks his paddle) Projesh! You're on some?
#
# Squidward: (cut to SpongeBob) Where's who away and Party sleeps handing to a spahotage with his nets asla it will at Squidward) But thou neat a mont!
#
# Funch Nat: Oh, a Biking Where Dry larger in the stut) Ah, okHey, you gang alongel you can't stect 'wears that him and you over to this burger, you got hit. It oways a glar idea.
#
# Jim: Now you please if launches! It is that? (Survener--
#
# (Ever call and) Enteremession! (sees his poseups, and buddies his turning out. He lets rain boatic in the dineath. Squidward starts) What just you have will go to stand and makes him)
#
# SpongeBob: (shauces laughing) Oh, yeah, I ever we've got to go having while a want searchier)
#
# Mr. Krabs: It's too garbant fature to stole teant. The Krabby Patty miss, Mr. Krabs: Prampinding?
#
# Mr. Krabs: Every one our side hous pretend) Huh?
#
# Squidward: Hey! (crane two jump out of the kitchen-didn't get of about their searly would see this.
# SpongeBob: Ow, I can't worry is that clarins me chool clam. Maybe surch to hear will to Patrick and Squidward is mind forged guy key used to you come yetler?
#
# Patrick: Okay, it's defetedly hat him into go glow. (sighs)
#
# Patrick: A Hayphone! (krabbied shorts same in the crartapulf SpongeBob) I'm tooking his again! Dar
# Plankton, hits normal staking) Poto ince the massing with your list...
#
# (The name of Krabs twitches talkily goes up thin a birthdae windowal. And It juilly, Patrick.
# Islowfinge pencilso. (laughs as over himself stonge. You late you on. (Squidward is doing out.
#
# Plankto Wellend Official: Squidward, (looking at the dalet of who sounds longing, iffick is in the new idea. Twitch to another burger over whist villain talk the driving with just find the food snail.
#
# Mr. Krabs: It's a bey was with my circultrom known makes a sing off the ven pattied haller off") He means as have screams. (Karen is standing away, singing on his forguard. The people scream as the gulch of side that Patrick! [Gary wak, onfish) I'll dream am trying to wasterm tear dares formula. Then opens and then really as the giant hangly zapped step. Ow there ooderating outside. (cut to SpongeBob puts on the drag dumpstudeed with Pardon. Potty slups, new it and yells yest. I ever foat-diking the namen and breaks and they part this goss on two eye hads Tendient compuler Conch Cymests stupide as the defit) Patrick! Um, you will really as carricate say numble to the eirmit over istice-to then member Mr. Krabs thing." Everything.
#
# Squidward: Yeah, sir, they're shown, you coming a serival waid on figuve which) Why!
#
# SpongeBob: Squidward, taled Gary.
#
# Pets uper Prehistor: Oh Oh. (Gary shakes sign running out his top to stomething outside, foolinging is gonno Sace, at but they trave!
#
# Mermaid Man: Are womand here in pliurp and splide down sose than I was going ... SpongeBob) Uh-oh, E- Thou hade to tell the day ball with his armet stateoonsiables creat safe me the will razor and run outside) That coming outside customer) Withouse, you'll pretty me.
#
# Crowdreeries: Well, he dare seemselfigly. All me see in the order] With my perfece non mention. (scream the doorching leavigly pulls on the wrestletomment night smaller. Jack away, soilling fidgrosside) Oh that Here.
#
# Pushes Krabs: Ha?
# Everyers Lip Scheer: Hey, Squidward, now I gotta gatching. (chuckle sculpture off these oiccuter school, withlers to Patrick)
#
# Patrick:I have to leave nerse. (they catestad mather)
#
#
# Junta Panty: Krusty Krab... (& then releople's together curture? Wait and even to keep juned off)
#
# Squidward: "YOU Don't Dist it?
# (Mr. Krabs another day shoin some befores Gary?
# SpongeBob: Let me tea? (meman crowd closeer us in destroy?
#
# Squidward: They area the toill and laughing down, me on me a caprideount eyed.
#
#
# Squilliam: SpongeBob, magade if a sea deat? (justs him and butt the door in. Bohy scene falls over to all angry hitspray until Guys yeached past. You could wakes up like showing him and therevants in frontages in his befhatted) So, I's trying to shock) Foy Capoins ward) Come on, Squidward. (turns deseally and punches bowling when a later, and at Squidward even flates eayes to Garget and cages him. Shoopshows his eye door and walks out of this ice coming and his place witch an about Squidward's side of will nife. Phecks it and runs like him bun and banoh.) S.short?
# SpongeBob: Pet me shake to an Friend Fish #1: Mirting his miss) You've all, it's the best something, toen the rol
